# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
# Out:
# 3.4.3

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Kategori')
plt.ylabel('jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.style.use('./style_u.mpstyle')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     114             try:
# --> 115                 rc = rc_params_from_file(style, use_default_template=False)
#     116                 _apply_style(rc)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     797     """
# --> 798     config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     799
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     726     rc_temp = {}
# --> 727     with _open_file_or_url(fname) as fd:
#     728         try:
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in _open_file_or_url(fname)
#     704             encoding = "utf-8"
# --> 705         with open(fname, encoding=encoding) as f:
#     706             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: './style_u.mpstyle'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10320/2754332601.py in <module>
# ----> 1 plt.style.use('./style_u.mpstyle')
#
# ~\anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     116                 _apply_style(rc)
#     117             except IOError as err:
# --> 118                 raise IOError(
#     119                     "{!r} not found in the style library and input is not a "
#     120                     "valid URL or path; see `style.available` for list of "
#
# OSError: './style_u.mpstyle' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Plot')

plt.show()

# %%
plt.style.use('ggplot')

plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
    
plt.show()
